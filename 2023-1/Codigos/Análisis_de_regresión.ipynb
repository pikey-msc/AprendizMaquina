# %% [markdown]
# # Análisis de regresión

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.metrics import accuracy_score, roc_auc_score, mean_absolute_error, r2_score

cf.go_offline()
pd.set_option("display.max_columns", 50)
pd.set_option('display.float_format', lambda x: "{:,.2f}".format(x))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Funciones relevantes

# %%
def normalize_content(texto):
    if texto in ['G', 'TV-G']:
        return "Publico General"
    if texto in ['R', 'NC-17', 'X']:
        return "Restricted"
    if texto in ['M', 'PG', 'GP', 'PG-13','TV-PG','TV-14'] :
        return "Parental Guiadance"
    if texto in ['Approved', 'Passed']:
        return "Approved"
    if texto in ['Not Rated', 'Unrated']:
        return "Not Rated"

# %%
def plot_histogram(df, feature):
    return df[[feature]].iplot(kind="hist", title = f"{feature} histogram", colors=["#296EAA"])

# %% [markdown]
# ## Carga de datos

# %%
df = pd.read_csv("../data/movies.csv")

# %%
df.shape
# Out:
# (5043, 16)

# %%
df.sample(5)
# Out:
#                                    movie_title  \
# 2949                            Despicable Me
# 2502                               The Pirate
# 922                              Fright Night
# 3800                          The Story of Us
# 2661  Things to Do in Denver When You're Dead
#
#                                         movie_imdb_link  color  genre_4  \
# 2949  http://www.imdb.com/title/tt1323594/?ref_=fn_t...  Color      NaN
# 2502  http://www.imdb.com/title/tt0040694/?ref_=fn_t...  Color  Romance
# 922   http://www.imdb.com/title/tt1438176/?ref_=fn_t...  Color      NaN
# 3800  http://www.imdb.com/title/tt0160916/?ref_=fn_t...  Color      NaN
# 2661  http://www.imdb.com/title/tt0114660/?ref_=fn_t...  Color      NaN
#
#       duration        gross    genre_1 genre_2  genre_3 num_voted_users  \
# 2949     87.00          nan  Animation  Comedy   Family          385943
# 2502    102.00 2,956,000.00  Adventure  Comedy  Musical            3258
# 922     106.00          nan     Comedy  Horror      NaN           85024
# 3800     95.00          nan     Comedy   Drama  Romance           18404
# 2661    115.00   529,766.00      Crime   Drama      NaN           22345
#
#      facenumber_in_poster language country content_rating  title_year  \
# 2949                    0  English     USA             PG    2,010.00
# 2502                    0  English     USA       Approved    1,948.00
# 922                     1  English     USA              R    2,011.00
# 3800                    1  English     USA              R    1,999.00
# 2661                    2  English     USA              R    1,995.00
#
#       imdb_score
# 2949        7.70
# 2502        7.10
# 922         6.40
# 3800        5.90
# 2661        6.80

# %% [markdown]
# ## Análisis exploratorio

# %%
ls_disc = ["color", "genre_4", "genre_1", "genre_2", "genre_3", "language", "country", "content_rating"]
ls_cont = ["duration", "gross", "num_voted_users", "facenumber_in_poster", "title_year"]
target = "imdb_score"

# %%
plot_histogram(df=df, feature=target)
# Out:
# <div>
#
#
#             <div id="fec64c29-e9ba-4a84-86fe-ba813e9d024c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fec64c29-e9ba-4a84-86fe-ba813e9d024c")) {
#                     Plotly.newPlot(
#                         'fec64c29-e9ba-4a84-86fe-ba813e9d024c',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba
3, 7.7, 6.4, 7.2, 5.9, 5.0, 6.4, 6.4, 7.4, 5.8, 4.3, 5.1, 5.9, 7.0, 7.0, 5.9, 4.5, 6.4, 8.0, 6.0, 6.2, 6.0, 6.5, 6.1, 5.4, 7.0, 6.0, 7.0, 7.2, 7.8, 6.3, 5.1, 8.3, 6.3, 7.1, 6.6, 6.3, 6.6, 6.8, 7.2, 6.6, 6.1, 6.9, 6.0, 5.3, 6.1, 6.6, 4.3, 7.5, 6.9, 8.6, 6.2, 5.3, 7.4, 7.5, 6.2, 7.4, 8.3, 6.2, 6.9, 6.5, 6.5, 6.4, 7.2, 7.3, 5.2, 7.4, 6.1, 7.0, 5.3, 6.9, 6.3, 3.5, 8.0, 6.2, 6.9, 7.5, 7.4, 7.1, 6.4, 6.7, 4.5, 7.0, 6.6, 6.4, 7.9, 8.7, 8.8, 6.2, 6.6, 6.8, 5.6, 7.0, 6.7, 7.2, 6.5, 8.1, 6.4, 6.4, 6.3, 4.9, 3.9, 7.4, 7.3, 5.9, 6.5, 7.2, 5.6, 6.4, 2.0, 7.4, 7.2, 6.9, 7.2, 7.8, 5.3, 7.2, 7.2, 8.6, 5.2, 7.9, 8.2, 6.3, 7.2, 4.6, 6.6, 7.2, 6.7, 5.8, 8.7, 4.4, 6.8, 8.6, 7.4, 6.7, 6.1, 4.1, 5.2, 5.7, 6.7, 6.2, 8.0, 6.1, 7.5, 5.5, 7.3, 7.9, 4.2, 8.4, 4.9, 6.5, 5.5, 5.8, 5.4, 5.8, 5.0, 5.1, 6.6, 6.6, 5.7, 6.3, 6.4, 6.7, 4.7, 7.9, 7.5, 6.2, 7.1, 8.0, 7.3, 8.0, 6.7, 6.7, 5.6, 5.6, 4.0, 6.7, 8.2, 7.5, 7.5, 4.6, 6.9, 5.8, 8.4, 6.9, 6.9, 6.7, 6.1, 6.5, 6.0, 6.1, 7.2, 6.2,  ...

# %%
df[ls_cont+[target]].describe(percentiles = [0.1, 0.5, 0.95, 0.99])
# Out:
#        duration          gross  title_year  imdb_score
# count  5,028.00       1,505.00    4,935.00    5,043.00
# mean     107.20  47,523,599.37    2,042.59        6.46
# std       25.20  70,034,507.15    2,818.52        1.71
# min        7.00         721.00    1,916.00        1.60
# 10%       86.00     335,377.20    1,988.00        5.00
# 50%      103.00  24,792,061.00    2,005.00        6.60
# 95%      146.00 177,159,421.40    2,015.00        8.10
# 99%      189.00 336,530,303.00    2,016.00        8.50
# max      511.00 760,505,847.00  200,000.00       98.00

# %%
df[df["gross"] >= 7.6*10**8]
# Out:
#      movie_title                                    movie_imdb_link  color  \
# 4425     Avatar   http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color
#
#      genre_4  duration          gross genre_1    genre_2  genre_3  \
# 4425  Sci-Fi    178.00 760,505,847.00  Action  Adventure  Fantasy
#
#      num_voted_users facenumber_in_poster language country content_rating  \
# 4425          886204                    0  English     USA          PG-13
#
#       title_year  imdb_score
# 4425    2,009.00        7.90

# %%
df[df[target] == 98]
# Out:
#      movie_title                                movie_imdb_link  color  \
# 3319   Sanctuary  nudity|party|pirate|swimsuit|three word title  Color
#
#      genre_4  duration  gross genre_1 genre_2   genre_3      num_voted_users  \
# 3319     NaN     82.00    nan  Comedy  Horror  Thriller   Quite a Conundrum
#
#      facenumber_in_poster language  country content_rating  title_year  \
# 3319           John Lucas        8  English            USA  200,000.00
#
#       imdb_score
# 3319       98.00

# %%
df = df[df[target] != 98].reset_index(drop = True)

# %%
df["num_voted_users"] = df["num_voted_users"].astype(float)

# %%
df[ls_cont+[target]].describe(percentiles = [0.1, 0.5, 0.95, 0.99])
# Out:
#        duration          gross  num_voted_users  title_year  imdb_score
# count  5,027.00       1,505.00         5,042.00    4,934.00    5,042.00
# mean     107.21  47,523,599.37        83,684.73    2,002.47        6.44
# std       25.20  70,034,507.15       138,493.99       12.48        1.13
# min        7.00         721.00             5.00    1,916.00        1.60
# 10%       86.00     335,377.20         1,649.70    1,988.00        5.00
# 50%      103.00  24,792,061.00        34,371.00    2,005.00        6.60
# 95%      146.00 177,159,421.40       332,265.45    2,015.00        8.09
# 99%      189.00 336,530,303.00       681,112.44    2,016.00        8.50
# max      511.00 760,505,847.00     1,689,764.00    2,016.00        9.50

# %%
for col in ls_disc:
    display(df[col].value_counts(True).reset_index())
# Out:
#               index  color
# 0             Color   0.96
# 1   Black and White   0.04
#        index  genre_4
# 0   Thriller     0.34
# 1    Romance     0.13
# 2     Family     0.10
# 3     Sci-Fi     0.08
# 4    Fantasy     0.07
# 5    Mystery     0.05
# 6        War     0.04
# 7      Drama     0.04
# 8      Sport     0.03
# 9    History     0.03
# 10   Musical     0.02
# 11     Music     0.02
# 12    Comedy     0.02
# 13   Western     0.02
# 14    Horror     0.01
# 15     Crime     0.01
# 16      News     0.00
#           index  genre_1
# 0        Comedy     0.26
# 1        Action     0.23
# 2         Drama     0.19
# 3     Adventure     0.09
# 4         Crime     0.07
# 5     Biography     0.05
# 6        Horror     0.05
# 7   Documentary     0.02
# 8     Animation     0.01
# 9       Fantasy     0.01
# 10      Mystery     0.01
# 11     Thriller     0.00
# 12       Sci-Fi     0.00
# 13      Western     0.00
# 14       Family     0.00
# 15      Romance     0.00
# 16      Musical     0.00
# 17      History     0.00
# 18        Music     0.00
# 19    Game-Show     0.00
# 20    Film-Noir     0.00
#           index  genre_2
# 0         Drama     0.27
# 1     Adventure     0.11
# 2         Crime     0.09
# 3       Romance     0.09
# 4        Comedy     0.08
# 5        Horror     0.05
# 6      Thriller     0.05
# 7       Mystery     0.05
# 8        Family     0.04
# 9       Fantasy     0.04
# 10    Animation     0.03
# 11       Sci-Fi     0.03
# 12        Music     0.02
# 13      History     0.02
# 14        Sport     0.01
# 15    Biography     0.01
# 16          War     0.01
# 17      Musical     0.01
# 18  Documentary     0.01
# 19      Western     0.00
# 20    Film-Noir     0.00
# 21        Short     0.00
# 22         News     0.00
# 23   Reality-TV     0.00
#           index  genre_3
# 0      Thriller     0.18
# 1       Romance     0.15
# 2         Drama     0.12
# 3        Sci-Fi     0.09
# 4       Fantasy     0.07
# 5        Family     0.06
# 6        Comedy     0.06
# 7       Mystery     0.06
# 8         Crime     0.04
# 9        Horror     0.03
# 10      History     0.03
# 11        Music     0.03
# 12        Sport     0.03
# 13          War     0.02
# 14      Musical     0.01
# 15    Animation     0.01
# 16      Western     0.01
# 17  Documentary     0.00
# 18    Biography     0.00
# 19        Short     0.00
# 20    Film-Noir     0.00
# 21   Reality-TV     0.00
# 22         News     0.00
#          index  language
# 0      English      0.93
# 1       French      0.01
# 2      Spanish      0.01
# 3        Hindi      0.01
# 4     Mandarin      0.01
# 5       German      0.00
# 6     Japanese      0.00
# 7      Italian      0.00
# 8      Russian      0.00
# 9    Cantonese      0.00
# 10      Korean      0.00
# 11  Portuguese      0.00
# 12      Danish      0.00
# 13      Hebrew      0.00
# 14     Swedish      0.00
# 15      Arabic      0.00
# 16     Persian      0.00
# 17       Dutch      0.00
# 18      Polish      0.00
# 19   Norwegian      0.00
# 20        Thai      0.00
# 21     Chinese      0.00
# 22   Icelandic      0.00
# 23        Dari      0.00
# 24  Aboriginal      0.00
# 25    Romanian      0.00
# 26        None      0.00
# 27  Indonesian      0.00
# 28        Zulu      0.00
# 29   Mongolian      0.00
# 30       Tamil      0.00
# 31        Urdu      0.00
# 32        Maya      0.00
# 33       Greek      0.00
# 34     Kannada      0.00
# 35       Czech      0.00
# 36    Dzongkha      0.00
# 37      Telugu      0.00
# 38     Panjabi      0.00
# 39   Slovenian      0.00
# 40     Bosnian      0.00
# 41   Hungarian      0.00
# 42  Vietnamese      0.00
# 43     Aramaic      0.00
# 44    Filipino      0.00
# 45      Kazakh      0.00
# 46     Swahili      0.00
#                  index  country
# 0                  USA     0.76
# 1                   UK     0.09
# 2               France     0.03
# 3               Canada     0.03
# 4              Germany     0.02
# ..                 ...      ...
# 60               Kenya     0.00
# 61             Bahamas     0.00
# 62               Aruba     0.00
# 63               Egypt     0.00
# 64  Dominican Republic     0.00
#
# [65 rows x 2 columns]
#         index  content_rating
# 0           R            0.45
# 1       PG-13            0.31
# 2          PG            0.15
# 3   Not Rated            0.02
# 4           G            0.02
# 5     Unrated            0.01
# 6    Approved            0.01
# 7       TV-14            0.01
# 8       TV-MA            0.00
# 9       TV-PG            0.00
# 10          X            0.00
# 11       TV-G            0.00
# 12     Passed            0.00
# 13      NC-17            0.00
# 14         GP            0.00
# 15          M            0.00
# 16      TV-Y7            0.00
# 17       TV-Y            0.00

# %%
df[ls_cont+ls_disc].isnull().sum() / len(df)
# Out:
# duration               0.00
# gross                  0.70
# num_voted_users        0.00
# facenumber_in_poster   0.00
# title_year             0.02
# color                  0.00
# genre_4                0.72
# genre_1                0.00
# genre_2                0.13
# genre_3                0.39
# language               0.00
# country                0.00
# content_rating         0.06
# dtype: float64

# %%
ls_drop = ["gross", "genre_4", "genre_3", "title_year"]

# %%
ls_cont = [x for x in ls_cont if x not in ls_drop]
ls_disc = [x for x in ls_disc if x not in ls_drop]

# %%
df = df.dropna(subset = ls_cont+ls_disc).reset_index(drop = True)

# %%
df.shape
# Out:
# (4168, 16)

# %%
df.sample(10)
# Out:
#                movie_title                                    movie_imdb_link  \
# 1882          Lord of War   http://www.imdb.com/title/tt0399295/?ref_=fn_t...
# 3364             Galaxina   http://www.imdb.com/title/tt0080771/?ref_=fn_t...
# 1692        Money Monster   http://www.imdb.com/title/tt2241351/?ref_=fn_t...
# 1051  The Matrix Reloaded   http://www.imdb.com/title/tt0234215/?ref_=fn_t...
# 948             Red Cliff   http://www.imdb.com/title/tt0425637/?ref_=fn_t...
# 2086          Chasing Amy   http://www.imdb.com/title/tt0118842/?ref_=fn_t...
# 28           Jack Reacher   http://www.imdb.com/title/tt0790724/?ref_=fn_t...
# 2381     The Mighty Ducks   http://www.imdb.com/title/tt0104868/?ref_=fn_t...
# 944              Unbroken   http://www.imdb.com/title/tt1809398/?ref_=fn_t...
# 2155         Timber Falls   http://www.imdb.com/title/tt0857295/?ref_=fn_t...
#
#       color   genre_4  duration          gross    genre_1    genre_2  \
# 1882  Color       NaN    122.00            nan      Crime      Drama
# 3364  Color       NaN     95.00            nan     Comedy     Sci-Fi
# 1692  Color       NaN     98.00            nan      Crime      Drama
# 1051  Color       NaN    138.00            nan     Action     Sci-Fi
# 948   Color   History    150.00            nan     Action  Adventure
# 2086  Color       NaN    113.00  12,006,514.00     Comedy      Drama
# 28    Color  Thriller    130.00            nan     Action      Crime
# 2381  Color     Sport    100.00            nan     Comedy      Drama
# 944   Color       War    137.00 115,603,980.00  Biography      Drama
# 2155  Color       NaN    100.00            nan     Horror   Thriller
#
#        genre_3  num_voted_users facenumber_in_poster  language country  \
# 1882  Thriller       248,123.00                    2   English     USA
# 3364       NaN         1,955.00                    0   English     USA
# 1692  Thriller        19,611.00                    1   English     USA
# 1051       NaN       421,818.00                    0   English     USA
# 948      Drama        36,894.00                    4  Mandarin   China
# 2086   Romance       114,070.00                    5   English     USA
# 28     Mystery       226,583.00                    2   English     USA
# 2381    Family        44,502.00                    8   English     USA
# 944      Sport       103,589.00                    0   English     USA
# 2155       NaN         5,012.00                    1   English     USA
#
#      content_rating  title_year  imdb_score
# 1882              R    2,005.00        7.60
# 3364              R    1,980.00        3.40
# 1692              R    2,016.00        6.70
# 1051              R    2,003.00        7.20
# 948               R    2,008.00        7.40
# 2086              R    1,997.00        7.30
# 28            PG-13    2,012.00        7.00
# 2381             PG    1,992.00        6.40
# 944           PG-13    2,014.00        7.20
# 2155              R    2,007.00        5.30

# %%
df["content_rating"] = df["content_rating"].map(normalize_content)

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### Preparación de sets

# %%
X = df.drop(columns=ls_disc)[ls_cont].join(pd.get_dummies(df[ls_disc]))
y = df[target]

# %%
X.shape
# Out:
# (4168, 134)

# %%
kb = SelectKBest(k = 5, score_func=f_regression)

# %%
kb.fit(X, y)
# Out:
# SelectKBest(k=5, score_func=<function f_regression at 0x7fdeb279ec80>)

# %%
ls_best = [x for x, y in zip(X.columns, kb.get_support()) if y]

# %%
ls_best
# Out:
# ['duration',
#  'num_voted_users',
#  'color_Color',
#  'genre_1_Biography',
#  'genre_2_Drama']

# %%
X = pd.DataFrame(kb.transform(X), columns = ls_best)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### Modelos

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linreg.predict(X_test)
# Out:
# array([6.57245058, 6.59749946, 6.50483826, ..., 5.9938558 , 6.13375507,
#        5.68030575])

# %%
r2_score(y_pred=linreg.predict(X_test), y_true=y_test)
# Out:
# 0.2879342533987256

# %%
linreg.coef_
# Out:
# array([ 4.99323784e-03,  2.95173089e-06, -6.48621090e-01,  4.85084328e-01,
#         3.47833170e-01])

# %%
linreg.coef_.round(3)
# Out:
# array([ 0.005,  0.   , -0.649,  0.485,  0.348])

# %%
mean_absolute_error(y_pred=linreg.predict(X_test), y_true=y_test)
# Out:
# 0.6781526953364576

# %%
yc_train = (y_train > y_train.mean())*1
yc_test = (y_test > y_train.mean())*1

# %%
y_train
# Out:
# 951    7.00
# 3531   5.50
# 3770   6.50
# 2768   6.70
# 68     7.70
#        ...
# 3026   4.10
# 2608   5.00
# 148    7.40
# 2835   5.40
# 228    6.70
# Name: imdb_score, Length: 3126, dtype: float64

# %%
yc_train
# Out:
# 3751    0
# 2492    0
# 1278    1
# 3117    1
# 3606    0
#        ..
# 3226    1
# 3329    0
# 1942    1
# 1458    0
# 2166    0
# Name: imdb_score, Length: 3126, dtype: int64

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, yc_train)
# Out:
# LogisticRegression()

# %%
roc_auc_score(y_score=logreg.predict_proba(X_test)[:,1],y_true=yc_test )
# Out:
# 0.5031405156427589

# %%
X_train[ls_best]
# Out:
#      duration num_voted_users color_Color genre_1_Biography genre_2_Drama
# 951    113.00       83,560.00           1                 0             0
# 3531    87.00        6,265.00           1                 0             0
# 3770   117.00       57,674.00           1                 0             0
# 2768    98.00       25,450.00           1                 0             1
# 68     109.00      181,025.00           1                 0             1
# ...       ...             ...         ...               ...           ...
# 3026    97.00       13,048.00           1                 0             0
# 2608    85.00       16,300.00           1                 0             0
# 148    135.00       90,932.00           1                 0             1
# 2835   105.00       39,782.00           1                 0             1
# 228     98.00       90,374.00           1                 0             0
#
# [3126 rows x 5 columns]

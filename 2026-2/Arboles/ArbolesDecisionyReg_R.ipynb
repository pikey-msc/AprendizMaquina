# %% [markdown]
# <a href="https://colab.research.google.com/github/pikey-msc/AprendizMaquina/blob/main/2026-2/Arboles/ArbolesDecisionyReg_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Carga de información GITHUB

# %%
try:
    # !rm -rf AprendizMaquina
except:
    print("No existe la ruta aún")



# !git clone 'https://github.com/pikey-msc/AprendizMaquina'
# Out:
# Cloning into 'AprendizMaquina'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 182 (delta 23), reused 0 (delta 0), pack-reused 66
# Receiving objects: 100% (182/182), 10.68 MiB | 19.46 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %% [markdown]
# #Carga de librerías

# %%
#Cargar módulo de R en Python
# A bit of imports
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Load in the r magic
# %reload_ext rpy2.ipython
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'

# %%
# %%R
# #install.packages("dplyr")
# library(dplyr) # "Libreria utilizada para manejar datos"
# library(rpart)
# install.packages("rpart.plot")
# library(rpart.plot)
# install.packages("caret")
# library(caret)
# install.packages("e1071")
# library(e1071)
# install.packages("ModelMetrics")
# library(ModelMetrics)
# install.packages("party")
# library(party)
# # install.packages("boot")
# # library(boot)
# # install.packages("ipred")
# # library(ipred)
# # install.packages("randomForest")
# # library(randomForest)
# # library(ggplot2)
# # install.packages("ISLR")
# # library(ISLR)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘dplyr’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/rpart.plot_3.1.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 672084 bytes (656 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 656 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmpzt0Yuw/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘future.apply’, ‘progressr’, ‘numDeriv’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘Rcpp’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.8.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 36762 bytes (35 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 35 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/parallelly_1.32.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 124853 bytes (121 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 121 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/future_1.28.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 366473 bytes (357 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 357 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/globals_0.16.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 35152 bytes (34 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 34 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/future.apply_1.9.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 65416 bytes (63 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 63 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/progressr_0.11.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 112113 bytes (109 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 109 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/numDeriv_2016.8-1.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 76053 bytes (74 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 74 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/SQUAREM_2021.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 241534 bytes (235 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 235 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/lava_1.6.10.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1631414 bytes (1.6 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.6 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/prodlim_2019.11.13.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 126048 bytes (123 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 123 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/proxy_0.4-27.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 74622 bytes (72 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 72 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/iterators_1.0.14.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 300266 bytes (293 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 293 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/Rcpp_1.0.9.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 2957812 bytes (2.8 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 505 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/coin_1.4-2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1225311 bytes (1.2 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.2 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/zoo_1.8-11.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 781934 bytes (763 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 763 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/sandwich_3.0-2.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1356080 bytes (1.3 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.3 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/party_1.3-10.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 763127 bytes (745 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 745 KB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmpzt0Yuw/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: grid
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: mvtnorm
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: modeltools
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: stats4
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: strucchange
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: zoo
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘zoo’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: sandwich

# %% [markdown]
# #Árboles de decisión
#
# **Algoritmos**\
# Existen diversos algoritmos para solucionar el problema anterior, cada uno utiliza metodologías distintas para particionar los datos así como para definir el criterio de paro del algorimo.
# * ID3
# * C4.5
#
# **Elementos**\
# Un árbol de decisión está formado por un conjunto de nodos de decisión (interiores) y de nodos-respuesta (hojas):
# * Un nodo de decisión está asociado a uno de los atributos y tiene 2 o más ramas que salen de él, cada una de ellas representando los posibles valores que puede tomar el atributo asociado. De alguna forma, un nodo de decisión es como una pregunta que se le hace al ejemplo analizado, y dependiendo de la respuesta que de, el flujo tomará una de las ramas salientes.
# * Un nodo-respuesta está asociado a la clasificación que se quiere proporcionar, y nos devuelve la decisión del árbol con respecto al ejemplo de entrada.
#
# **ID3**\
# El ID3 construye un árbol de decisión de arriba a abajo, de forma directa, sin hacer uso de backtracking, y basándose únicamente en los ejemplos iniciales proporcionados. Para ello, usa el concepto de Ganancia de Información para seleccionar el atributo más útil en cada paso.\
# En cierta forma, sigue un método voraz para decidir la pregunta que mayor ganancia da en cada paso, es decir, aquella que me permite separar mejor los ejemplos entre sí respecto a la clasificación final.
#
# **Informacion**\
# La medida que se utiliza se llama entropía y se utiliza para clasificar los elementos procurando:
# * Muestra completamente homogénea (es decir, en la que todos se clasifican igual).En este caso, fijaremos la incertidumbre (entropía) a 0
# * Muestra igualmente distribuida, es decir, que tiene el mismo número de ejemplos.En este caso, fijaremos la incertidumbre (entropía) a 1
#
# Para medir la incertidumbre de un sistema. Shannon llega a la conclusión de que la mejor función matemática que mide este grado de incertidumbre es la siguiente:
#
# $$\textrm{Information Gain}=IG=\sum_{i=1}^c -p_ilog_2(p_i)$$
#
# donde $S$ es el conjunto de muestras (el sistema analizado), $C$ es el número de diferentes clasificaciones que usamos, y cada $p_i$ es la proporción de ejemplos que hay de la clasificación $i$ en la muestra.
#
# **Ejemplo teórico**\
# El algoritmo ID3 se ejecuta recursivamente en nodos que no sean de respuesta (hojas) hasta llegar al caso de entropía nula.

# %% [markdown]
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %%
# %%R
# EG=-5/(9+5)*log(5/(9+5),2)-9/(9+5)*log(9/(9+5),2)
# EG
# Out:
# [1] 0.940286

# %% [markdown]
# Paso 1. Antes de realizar ninguna división por atributos, la entropía del sistema es:
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Paso 2. Calcula la ganancia que obtendríamos si hicieramos una división usando el primer atributo (Outlook):
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %%
# %%R
# print("Outlook")
# print(((-3/(5)*log(3/5,2)-2/(5)*log(2/5,2))*5/14)*2)
# print(EG-((-3/(5)*log(3/5,2)-2/(5)*log(2/5,2))*5/14)*2)
#
# print("Temp")
# print(EG-((-2/(4)*log(2/4,2)-2/(4)*log(2/4,2))*4/14 + (-4/(6)*log(4/6,2)-2/(6)*log(2/6,2))*6/14 + (-3/(4)*log(3/4,2)-1/(4)*log(1/4,2))*4/14))
# Out:
# [1] "Outlook"
# [1] 0.6935361
# [1] 0.2467498
# [1] "Temp"
# [1] 0.02922257

# %% [markdown]
# Paso 3. Se repite con cada uno de los atributos que tienen los ejemplos:
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Paso 4. Se queda con el atributo que proporciona mayor ganancia (en este caso, Outlook), con lo que tenemos construido el primer paso del árbol de decisión, identificando el primer nodo de decisión:
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Paso 5. A continuación nos situamos en cada uno de los subconjuntos de ejemplos que define cada valor del atributo seleccionado y repetimos el proceso, construyendo poco a poco el árbol completo de decisión. Un nodo que tenga entropía nula se convierte en un nodo respuesta, ya que representa una muestra homogénea en el que la clasificación final es la misma para todos los ejemplos que contiene:
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Uno de los aspectos más interesantes que nos ofrecen los árboles de decisión como máquinas de predicción es que nos permiten explicar porqué un determinado ejemplo se clasifica de una cierta forma, y podemos extraer un procedimiento que se implementa fácilmente en cualquier sistema haciendo uso de reglas condicionales.
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# **Ventajas**
# * Son fáciles de entender, interpretar y explicar
# * No requieren de mucho trabajo previo en preparar la base de datos de entrenamiento
# * Funcionan con datos numéricos y categóricos
# * Trabajan con datos no lineales
# * Se pueden hacer pruebas estadísticas sobre los resultados, lo cual da mayor confianza al modelo
# * Es robusto, funciona incluso si los datos no cumplen con los supuestos
# * Es escalable a bases de datos grandes
#
# **Desventajas y limitaciones**
# * Alcanzar un óptimo global es un problema, por lo tanto se utilizan heurísticas para encontrar la solución al problema de optimización
# * Pequeños cambios en los datos puede resultar en cambios radicales en la segmentación del arbol
# * Alta varianza
# * El tamaño y complejidad del árbol puede ser muy alto

# %% [markdown]
# ###Ejemplo. Arbol decision datos IRIS
# **Separación en conjunto de entrenamiendo y prueba**
# Al igual que en la clase anterior separemos la base de datos en el conjunto de entrenamiento y prueba.

# %%
# %%R
# data(iris)
# print(head(iris))
# # Muestra del 80% del total
#
# smp_size <- floor(0.80 * nrow(iris))
#
# # fijar la semilla para que la muestra pueda ser reproducible
# # 42 es la respuesta al sentido de la vida, el universo y todo lo demás
#
# set.seed(42)
#
# train_ind <- sample(seq_len(nrow(iris)), size = smp_size)
#
# train <- iris[train_ind, ]
# test <- iris[-train_ind, ]
# print("tamaño de conjunto de entrenamiento:")
# print(nrow(train))
# print("tamaño de conjunto de prueba:")
# print(nrow(test))
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9         3.0          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5          5.0         3.6          1.4         0.2  setosa
# 6          5.4         3.9          1.7         0.4  setosa
# [1] "tamaño de conjunto de entrenamiento:"
# [1] 120
# [1] "tamaño de conjunto de prueba:"
# [1] 30

# %% [markdown]
# Calcular árbol de decisión

# %%
# %%R
# part_tree <- rpart(Species ~ .,  data = train, method = "class",
#                    minsplit = 5)
#
# summary(part_tree)
# Out:
# Call:
# rpart(formula = Species ~ ., data = train, method = "class",
#     minsplit = 5)
#   n= 120
#
#           CP nsplit  rel error     xerror       xstd
# 1 0.50632911      0 1.00000000 1.21518987 0.05546558
# 2 0.44303797      1 0.49367089 0.64556962 0.06854755
# 3 0.02531646      2 0.05063291 0.08860759 0.03249904
# 4 0.01000000      3 0.02531646 0.08860759 0.03249904
#
# Variable importance
#  Petal.Width Petal.Length Sepal.Length  Sepal.Width
#           34           33           21           12
#
# Node number 1: 120 observations,    complexity param=0.5063291
#   predicted class=setosa      expected loss=0.6583333  P(node) =1
#     class counts:    41    39    40
#    probabilities: 0.342 0.325 0.333
#   left son=2 (41 obs) right son=3 (79 obs)
#   Primary splits:
#       Petal.Length < 2.45 to the left,  improve=40.48966, (0 missing)
#       Petal.Width  < 0.8  to the left,  improve=40.48966, (0 missing)
#       Sepal.Length < 5.45 to the left,  improve=27.81444, (0 missing)
#       Sepal.Width  < 3.15 to the right, improve=13.53936, (0 missing)
#   Surrogate splits:
#       Petal.Width  < 0.8  to the left,  agree=1.000, adj=1.000, (0 split)
#       Sepal.Length < 5.45 to the left,  agree=0.917, adj=0.756, (0 split)
#       Sepal.Width  < 3.35 to the right, agree=0.808, adj=0.439, (0 split)
#
# Node number 2: 41 observations
#   predicted class=setosa      expected loss=0  P(node) =0.3416667
#     class counts:    41     0     0
#    probabilities: 1.000 0.000 0.000
#
# Node number 3: 79 observations,    complexity param=0.443038
#   predicted class=virginica   expected loss=0.4936709  P(node) =0.6583333
#     class counts:     0    39    40
#    probabilities: 0.000 0.494 0.506
#   left son=6 (41 obs) right son=7 (38 obs)
#   Primary splits:
#       Petal.Width  < 1.65 to the left,  improve=31.985330, (0 missing)
#       Petal.Length < 4.85 to the left,  improve=30.143220, (0 missing)
#       Sepal.Length < 6.35 to the left,  improve= 9.191252, (0 missing)
#       Sepal.Width  < 2.45 to the left,  improve= 3.173036, (0 missing)
#   Surrogate splits:
#       Petal.Length < 4.75 to the left,  agree=0.899, adj=0.789, (0 split)
#       Sepal.Length < 6.25 to the left,  agree=0.734, adj=0.447, (0 split)
#       Sepal.Width  < 2.95 to the left,  agree=0.646, adj=0.263, (0 split)
#
# Node number 6: 41 observations,    complexity param=0.02531646
#   predicted class=versicolor  expected loss=0.07317073  P(node) =0.3416667
#     class counts:     0    38     3
#    probabilities: 0.000 0.927 0.073
#   left son=12 (37 obs) right son=13 (4 obs)
#   Primary splits:
#       Petal.Length < 4.95 to the left,  improve=4.0609760, (0 missing)
#       Sepal.Length < 6.85 to the left,  improve=0.7661038, (0 missing)
#       Petal.Width  < 1.35 to the left,  improve=0.4609756, (0 missing)
#       Sepal.Width  < 2.25 to the right, improve=0.2771918, (0 missing)
#
# Node number 7: 38 observations
#   predicted class=virginica   expected loss=0.02631579  P(node) =0.3166667
#     class counts:     0     1    37
#    probabilities: 0.000 0.026 0.974
#
# Node number 12: 37 observations
#   predicted class=versicolor  expected loss=0  P(node) =0.3083333
#     class counts:     0    37     0
#    probabilities: 0.000 1.000 0.000
#
# Node number 13: 4 observations
#   predicted class=virginica   expected loss=0.25  P(node) =0.03333333
#     class counts:     0     1     3
#    probabilities: 0.000 0.250 0.750

# %% [markdown]
# Visualizar el árbol

# %%
# %%R
# rpart.plot(part_tree)

# %% [markdown]
# Importancia de cada parámetro

# %%
# %%R
# part_tree$variable.importance
# Out:
#  Petal.Width Petal.Length Sepal.Length  Sepal.Width
#     72.47499     69.80221     44.92336     26.19314

# %% [markdown]
# #### Ejercicio probar en el conjunto de validación

# %% [markdown]
# #### Ejercicio Datos IRIS Python

# %% [markdown]
# ### Ejercicio de Crédito Banco Alemán

# %%
# %%R
# credit <- read.table("AprendizMaquina/2023-1/Regresion/Datos/credit.txt")
#
# credit=mutate(credit,V21=as.factor(V21))
#
# cred_nam=c("Status of existing checking account","Duration in month","Credit history","Purpose","Credit amount","Present employment since","Installment rate in percentage of disposable income","Personal status and sex","Other debtors / guarantors","Present residence since","Property","A124 : unknown / no property","Age in years","Other installment plans","Housing","Number of existing credits at this bank","Job","Number of people being liable to provide maintenance for","Telephone","foreign worker", "V21")
#
# names(credit)=cred_nam
#
# names(credit)<-make.names(names(credit))
#
# print(summary(credit))
# # Define el numero total de renglones de los datos
#
# n <- nrow(credit)
#
# ## Define el número de renglones para el conjunto de entrenamiento (80% de la base de datos)
#
# n_train <- round(n * .80)
#
# ## Crea un vector de indices que sea el 80% de la muestra aleatoria
#
# set.seed(2^25)
#
# train_indices <- sample(seq_len(n), size = n_train)
#
# # Obten el conjunto de indices para los datos de entrenamiento
#
# credit_train <- credit[train_indices,]#
# print("Tamaño datos entrenamiento:")
# print(nrow(credit_train))
# # Excluye los indices de entrenamiento para crear el conjunto de prueba
#
#  credit_test <- credit[-train_indices, ]
# print("Tamaño datos prueba:")
# print(nrow(credit_test))
# # Utiliza el data frame de credit_train para con los datos de entrenamiento crear un arbol de decision
# Out:
#  Status.of.existing.checking.account Duration.in.month Credit.history
#  Length:1000                         Min.   : 4.0      Length:1000
#  Class :character                    1st Qu.:12.0      Class :character
#  Mode  :character                    Median :18.0      Mode  :character
#                                      Mean   :20.9
#                                      3rd Qu.:24.0
#                                      Max.   :72.0
#    Purpose          Credit.amount   Present.employment.since
#  Length:1000        Min.   :  250   Length:1000
#  Class :character   1st Qu.: 1366   Class :character
#  Mode  :character   Median : 2320   Mode  :character
#                     Mean   : 3271
#                     3rd Qu.: 3972
#                     Max.   :18424
#  Installment.rate.in.percentage.of.disposable.income Personal.status.and.sex
#  Length:1000                                         Min.   :1.000
#  Class :character                                    1st Qu.:2.000
#  Mode  :character                                    Median :3.000
#                                                      Mean   :2.973
#                                                      3rd Qu.:4.000
#                                                      Max.   :4.000
#  Other.debtors...guarantors Present.residence.since    Property
#  Length:1000                Length:1000             Min.   :1.000
#  Class :character           Class :character        1st Qu.:2.000
#  Mode  :character           Mode  :character        Median :3.000
#                                                     Mean   :2.845
#                                                     3rd Qu.:4.000
#                                                     Max.   :4.000
#  A124...unknown...no.property  Age.in.years   Other.installment.plans
#  Length:1000                  Min.   :19.00   Length:1000
#  Class :character             1st Qu.:27.00   Class :character
#  Mode  :character             Median :33.00   Mode  :character
#                               Mean   :35.55
#                               3rd Qu.:42.00
#                               Max.   :75.00
#    Housing          Number.of.existing.credits.at.this.bank     Job
#  Length:1000        Min.   :1.000                           Length:1000
#  Class :character   1st Qu.:1.000                           Class :character
#  Mode  :character   Median :1.000                           Mode  :character
#                     Mean   :1.407
#                     3rd Qu.:2.000
#                     Max.   :4.000
#  Number.of.people.being.liable.to.provide.maintenance.for  Telephone
#  Min.   :1.000                                            Length:1000
#  1st Qu.:1.000                                            Class :character
#  Median :1.000                                            Mode  :character
#  Mean   :1.155
#  3rd Qu.:1.000
#  Max.   :2.000
#  foreign.worker     V21
#  Length:1000        1:700
#  Class :character   2:300
#  Mode  :character
#
#
#
# [1] "Tamaño datos entrenamiento:"
# [1] 800
# [1] "Tamaño datos prueba:"
# [1] 200

# %%
# %%R
# summary(as.factor(credit$V21))
# creditb=credit[credit$V21==1,]
# creditm=credit[credit$V21==2,]
#
# #Selección de muestra de entrenamiento de buenos (200)
# tb <- sample(1:700,200)
# credit_trainb <- creditb[tb,]
# credit_testb <- creditb[-tb,]
#
# #Selección de muestra de entrenamiento de malos (200)
# tm <- sample(1:300,200)
# credit_trainm <- creditm[tm,]
# credit_testm <- creditm[-tm,]
#
# credit_train=rbind(credit_trainb,credit_trainm)
# credit_test=rbind(credit_testb,credit_testm)
#
# print(nrow(credit_train))
# print(nrow(credit_test))
# Out:
# [1] 400
# [1] 600

# %% [markdown]
# Calcular el modelo

# %%
# %%R
# # Define el modelo de entrenamiento
#
# credit_model <- rpart(formula = as.factor(V21)~.,
#                       data = credit_train,
#                       method = "class",parms = list(split = "information") )
# rpart.plot(credit_model)
# # Observa las salidas del modelo
#
# print(credit_model)
#
# # Genera la clase de predicción para los datos de "credit_test"
#
# # Utiliza la matriz de confusión para los datos prueba
#
# # Genera el modelo de predicción
#  class_prediction <- predict(object =credit_model,
#                         newdata = credit_test,
#                         type = "class")
#
# # Calcula la matriz de confusión para el conjunto de datos prueba
#  confusionMatrix(as.factor(credit_test$V21), class_prediction)
# Out:
# n= 400
#
# node), split, n, loss, yval, (yprob)
#       * denotes terminal node
#
#  1) root 400 200 1 (0.5000000 0.5000000)
#    2) Status.of.existing.checking.account=A13,A14 156  42 1 (0.7307692 0.2692308)
#      4) Other.installment.plans=A143 129  28 1 (0.7829457 0.2170543) *
#      5) Other.installment.plans=A141,A142 27  13 2 (0.4814815 0.5185185)
#       10) Purpose=A41,A43 9   2 1 (0.7777778 0.2222222) *
#       11) Purpose=A40,A42,A46,A49 18   6 2 (0.3333333 0.6666667) *
#    3) Status.of.existing.checking.account=A11,A12 244  86 2 (0.3524590 0.6475410)
#      6) Duration.in.month< 20.5 116  56 2 (0.4827586 0.5172414)
#       12) Purpose=A41,A43,A49 40  11 1 (0.7250000 0.2750000)
#         24) Number.of.existing.credits.at.this.bank>=1.5 10   0 1 (1.0000000 0.0000000) *
#         25) Number.of.existing.credits.at.this.bank< 1.5 30  11 1 (0.6333333 0.3666667)
#           50) A124...unknown...no.property=A121,A122 23   5 1 (0.7826087 0.2173913) *
#           51) A124...unknown...no.property=A123,A124 7   1 2 (0.1428571 0.8571429) *
#       13) Purpose=A40,A42,A44,A45,A46 76  27 2 (0.3552632 0.6447368)
#         26) Age.in.years>=34.5 28  12 1 (0.5714286 0.4285714)
#           52) Installment.rate.in.percentage.of.disposable.income=A71,A72,A74 7   0 1 (1.0000000 0.0000000) *
#           53) Installment.rate.in.percentage.of.disposable.income=A73,A75 21   9 2 (0.4285714 0.5714286) *
#         27) Age.in.years< 34.5 48  11 2 (0.2291667 0.7708333) *
#      7) Duration.in.month>=20.5 128  30 2 (0.2343750 0.7656250) *
#      [,1] [,2]
# [1,]    0    0
# [2,]    0  500

# %%
# %%R
# rpart.plot(credit_model)

# %%
# %%R
#  class_prediction <- predict(object =credit_model,
#                         newdata = credit_test,
#                         type = "class")
# print(summary(as.factor(credit_test$V21)))
# print(head(class_prediction))
# # Calcula la matriz de confusión para el conjunto de datos prueba
#  table(credit_test$V21, as.factor(class_prediction))
# Out:
#   1   2
# 500 100
#  8 13 17 18 21 22
#  2  2  1  2  1  1
# Levels: 1 2
#
#       1   2
#   1 325 175
#   2  28  72

# %% [markdown]
# #### Ejercicio Crédito Python

# %% [markdown]
# ##Método de segmentación Gini
# La idea de la segmentación del arbol es crear segmentaciones puras
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Sin embargo, esto no es posible, por lo que los algoritmos de segmentación del arbol crearan regiones lo mas puras posible.\
# La segmentación de Gini busca obtener grupos mas homogeneos
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Por tanto, es una escala que permite medir que tan puro es el modelo.
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Entre mas puro es el modelo, menor sera el indice de Gini y viceversa.\
# Ejemplo de datos de crédito con modelo de Gini.
# Compara dos modelos que utilizan dos criterios diferentes (gini o information) y utiliza la validacion para escoger el mejor modelo de este grupo.
#
# 1. Modelo 1 con la condición split = gini
#
# 2. Modelo 2 con la condicion split = information
#
# 3. Genera predicciones sobre el conjunto de validaciones de ambos modelos
#
# 4. La clasificación del error “ce()” es la fracción incorrectamente clasificada de instancias. Computa y compara los datos prueba de ambos modelos.

# %%
# %%R
#  # Modelo Gini
#  credit_model1 <- rpart(formula = V21 ~ .,
#                         data = credit_train,
#                         method = "class",
#                         parms = list(split = "gini"))
#  summary(credit_model1)
#  rpart.plot(credit_model1)
#  # Modelo information
#  credit_model2 <- rpart(formula = V21 ~ .,
#                         data = credit_train,
#                         method = "class",
#                         parms = list(split = "information"))
#  rpart.plot(credit_model2)
#
#  # Genera predicciones a partir del modelo de Gini
#  pred1 <- predict(object =credit_model1,
#                   newdata = credit_test,
#                   type = "class")
#
#  # Genera predicciones a partir del modelo de Information
#  pred2 <- predict(object =credit_model2,
#                   newdata = credit_test,
#                   type = "class")
#
#  # Comparacion de modelo clasificacion
# Out:
# Call:
# rpart(formula = V21 ~ ., data = credit_train, method = "class",
#     parms = list(split = "gini"))
#   n= 400
#
#       CP nsplit rel error xerror       xstd
# 1 0.3600      0     1.000  1.080 0.04983974
# 2 0.0450      1     0.640  0.655 0.04693013
# 3 0.0200      3     0.550  0.655 0.04693013
# 4 0.0150      4     0.530  0.715 0.04792638
# 5 0.0125      7     0.485  0.705 0.04777486
# 6 0.0100      9     0.460  0.715 0.04792638
#
# Variable importance
#                 Status.of.existing.checking.account
#                                                  28
#                                             Purpose
#                                                  14
#                                   Duration.in.month
#                                                  11
#                            Present.employment.since
#                                                   9
# Installment.rate.in.percentage.of.disposable.income
#                                                   8
#                                        Age.in.years
#                                                   8
#                                       Credit.amount
#                                                   6
#                          Other.debtors...guarantors
#                                                   5
#                             Other.installment.plans
#                                                   4
#                        A124...unknown...no.property
#                                                   4
#                                                 Job
#                                                   2
#                                      Credit.history
#                                                   1
#                                           Telephone
#                                                   1
#
# Node number 1: 400 observations,    complexity param=0.36
#   predicted class=1  expected loss=0.5  P(node) =1
#     class counts:   200   200
#    probabilities: 0.500 0.500
#   left son=2 (156 obs) right son=3 (244 obs)
#   Primary splits:
#       Status.of.existing.checking.account splits as  RRLL,       improve=27.23834, (0 missing)
#       Present.employment.since            splits as  RRLLL,      improve=14.62962, (0 missing)
#       Duration.in.month                   < 15.5   to the left,  improve=14.20765, (0 missing)
#       Age.in.years                        < 34.5   to the right, improve=12.71488, (0 missing)
#       Purpose                             splits as  RLRRLLRRLR, improve=11.70483, (0 missing)
#   Surrogate splits:
#       Present.employment.since splits as  RRLLL,      agree=0.682, adj=0.186, (0 split)
#       Duration.in.month        < 6.5    to the left,  agree=0.620, adj=0.026, (0 split)
#       Credit.history           splits as  RRRRL,      agree=0.620, adj=0.026, (0 split)
#       Purpose                  splits as  RRRRRRRRLL, agree=0.618, adj=0.019, (0 split)
#       Age.in.years             < 61.5   to the right, agree=0.615, adj=0.013, (0 split)
#
# Node number 2: 156 observations,    complexity param=0.015
#   predicted class=1  expected loss=0.2692308  P(node) =0.39
#     class counts:   114    42
#    probabilities: 0.731 0.269
#   left son=4 (129 obs) right son=5 (27 obs)
#   Primary splits:
#       Other.installment.plans                             splits as  RRL,        improve=4.058173, (0 missing)
#       Duration.in.month                                   < 25.5   to the left,  improve=3.744310, (0 missing)
#       Installment.rate.in.percentage.of.disposable.income splits as  RRRLL,      improve=3.404831, (0 missing)
#       Purpose                                             splits as  RL-RLLLRLR, improve=3.380926, (0 missing)
#       Present.employment.since                            splits as  RLLLL,      improve=2.710277, (0 missing)
#   Surrogate splits:
#       Number.of.existing.credits.at.this.bank < 2.5    to the left,  agree=0.846, adj=0.111, (0 split)
#       Duration.in.month                       < 45     to the left,  agree=0.840, adj=0.074, (0 split)
#       Credit.history                          splits as  LRLLL,      agree=0.833, adj=0.037, (0 split)
#       Job                                     splits as  RLLL,       agree=0.833, adj=0.037, (0 split)
#
# Node number 3: 244 observations,    complexity param=0.045
#   predicted class=2  expected loss=0.352459  P(node) =0.61
#     class counts:    86   158
#    probabilities: 0.352 0.648
#   left son=6 (116 obs) right son=7 (128 obs)
#   Primary splits:
#       Duration.in.month            < 20.5   to the left,  improve=7.508515, (0 missing)
#       Age.in.years                 < 34.5   to the right, improve=6.890563, (0 missing)
#       A124...unknown...no.property splits as  LLRR,       improve=6.754325, (0 missing)
#       Purpose                      splits as  RLRRLLRR-R, improve=5.149988, (0 missing)
#       Credit.amount                < 4023.5 to the left,  improve=5.033854, (0 missing)
#   Surrogate splits:
#       Credit.amount                < 1931.5 to the left,  agree=0.738, adj=0.448, (0 split)
#       A124...unknown...no.property splits as  LRRR,       agree=0.643, adj=0.250, (0 split)
#       Purpose                      splits as  LRRRLRLR-R, agree=0.611, adj=0.181, (0 split)
#       Other.debtors...guarantors   splits as  RLRL,       agree=0.602, adj=0.164, (0 split)
#       Job                          splits as  LLRR,       agree=0.574, adj=0.103, (0 split)
#
# Node number 4: 129 observations,    complexity param=0.0125
#   predicted class=1  expected loss=0.2170543  P(node) =0.3225
#     class counts:   101    28
#    probabilities: 0.783 0.217
#   left son=8 (108 obs) right son=9 (21 obs)
#   Primary splits:
#       Installment.rate.in.percentage.of.disposable.income splits as  RRLLL,      improve=3.368771, (0 missing)
#       Credit.history                                      splits as  L-LRL,      improve=2.986871, (0 missing)
#       Age.in.years                                        < 34.5   to the right, improve=2.945442, (0 missing)
#       Credit.amount                                       < 6304.5 to the left,  improve=2.118466, (0 missing)
#       Present.employment.since                            splits as  RRLLL,      improve=1.957152, (0 missing)
#   Surrogate splits:
#       Age.in.years  < 23.5   to the right, agree=0.853, adj=0.095, (0 split)
#       Credit.amount < 641.5  to the right, agree=0.845, adj=0.048, (0 split)
#
# Node number 5: 27 observations,    complexity param=0.015
#   predicted class=2  expected loss=0.4814815  P(node) =0.0675
#     class counts:    13    14
#    probabilities: 0.481 0.519
#   left son=10 (9 obs) right son=11 (18 obs)
#   Primary splits:
#       Purpose                                             splits as  RL-RL--R-R, improve=2.370370, (0 missing)
#       Credit.history                                      splits as  LLLLR,      improve=1.814815, (0 missing)
#       Present.employment.since                            splits as  RLLLR,      improve=1.639376, (0 missing)
#       Installment.rate.in.percentage.of.disposable.income splits as  RRRRL,      improve=1.639376, (0 missing)
#       A124...unknown...no.property                        splits as  RRLL,       improve=1.617845, (0 missing)
#   Surrogate splits:
#       Credit.history               splits as  RLRLR,      agree=0.741, adj=0.222, (0 split)
#       Credit.amount                < 8401   to the right, agree=0.741, adj=0.222, (0 split)
#       Present.employment.since     splits as  RLRRR,      agree=0.704, adj=0.111, (0 split)
#       A124...unknown...no.property splits as  RRLR,       agree=0.704, adj=0.111, (0 split)
#       Age.in.years                 < 34.5   to the left,  agree=0.704, adj=0.111, (0 split)
#
# Node number 6: 116 observations,    complexity param=0.045
#   predicted class=2  expected loss=0.4827586  P(node) =0.29
#     class counts:    56    60
#    probabilities: 0.483 0.517
#   left son=12 (40 obs) right son=13 (76 obs)
#   Primary splits:
#       Purpose                      splits as  RL-RLRRR-L, improve=7.165245, (0 missing)
#       Age.in.years                 < 34.5   to the right, improve=6.864858, (0 missing)
#       A124...unknown...no.property splits as  LLRR,       improve=3.481604, (0 missing)
#       Credit.history               splits as  RRLLL,      improve=3.206506, (0 missing)
#       Other.installment.plans      splits as  RRL,        improve=2.620265, (0 missing)
#   Surrogate splits:
#       Other.debtors...guarantors   splits as  RRRL,       agree=0.707, adj=0.150, (0 split)
#       Age.in.years                 < 47.5   to the right, agree=0.690, adj=0.100, (0 split)
#       Present.employment.since     splits as  RRLRR,      agree=0.681, adj=0.075, (0 split)
#       A124...unknown...no.property splits as  LRRR,       agree=0.681, adj=0.075, (0 split)
#       Credit.amount                < 416.5  to the left,  agree=0.672, adj=0.050, (0 split)
#
# Node number 7: 128 observations
#   predicted class=2  expected loss=0.234375  P(node) =0.32
#     class counts:    30    98
#    probabilities: 0.234 0.766
#
# Node number 8: 108 observations
#   predicted class=1  expected loss=0.1666667  P(node) =0.27
#     class counts:    90    18
#    probabilities: 0.833 0.167
#
# Node number 9: 21 observations,    complexity param=0.0125
#   predicted class=1  expected loss=0.4761905  P(node) =0.0525
#     class counts:    11    10
#    probabilities: 0.524 0.476
#   left son=18 (8 obs) right son=19 (13 obs)
#   Primary splits:
#       Present.employment.since                splits as  RL--L,      improve=3.187729, (0 missing)
#       Purpose                                 splits as  LL-RL--RLR, improve=2.912554, (0 missing)
#       Property                                < 2.5    to the right, improve=1.937729, (0 missing)
#       Number.of.existing.credits.at.this.bank < 1.5    to the left,  improve=1.937729, (0 missing)
#       Credit.amount                           < 3506   to the left,  improve=1.190476, (0 missing)
#   Surrogate splits:
#       Purpose                      splits as  LL-RR--RRR, agree=0.857, adj=0.625, (0 split)
#       Age.in.years                 < 43.5   to the right, agree=0.810, adj=0.500, (0 split)
#       A124...unknown...no.property splits as  LRR-,       agree=0.714, adj=0.250, (0 split)
#       Credit.amount                < 2653.5 to the right, agree=0.667, adj=0.125, (0 split)
#       Other.debtors...guarantors   splits as  RRLR,       agree=0.667, adj=0.125, (0 split)
#
# Node number 10: 9 observations
#   predicted class=1  expected loss=0.2222222  P(node) =0.0225
#     class counts:     7     2
#    probabilities: 0.778 0.222
#
# Node number 11: 18 observations
#   predicted class=2  expected loss=0.3333333  P(node) =0.045
#     class counts:     6    12
#    probabilities: 0.333 0.667
#
# Node number 12: 40 observations
#   predicted class=1  expected loss=0.275  P(node) =0.1
#     class counts:    29    11
#    probabilities: 0.725 0.275
#
# Node number 13: 76 observations,    complexity param=0.02
#   predicted class=2  expected loss=0.3552632  P(node) =0.19
#     class counts:    27    49
#    probabilities: 0.355 0.645
#   left son=26 (28 obs) right son=27 (48 obs)
#   Primary splits:
#       Age.in.years            < 34.5   to the right, improve=4.143170, (0 missing)
#       Other.installment.plans splits as  RLL,        improve=2.429953, (0 missing)
#       Credit.history          splits as  RRRLL,      improve=2.232267, (0 missing)
#       Duration.in.month       < 11.5   to the left,  improve=1.648690, (0 missing)
#       Credit.amount           < 991.5  to the right, improve=1.400037, (0 missing)
#   Surrogate splits:
#       Installment.rate.in.percentage.of.disposable.income splits as  RRRRL,      agree=0.737, adj=0.286, (0 split)
#       Other.debtors...guarantors                          splits as  LRLR,       agree=0.711, adj=0.214, (0 split)
#       Telephone                                           splits as  RL,         agree=0.711, adj=0.214, (0 split)
#       Credit.amount                                       < 4063   to the right, agree=0.697, adj=0.179, (0 split)
#       Job                                                 splits as  RRRL,       agree=0.697, adj=0.179, (0 split)
#
# Node number 18: 8 observations
#   predicted class=1  expected loss=0.125  P(node) =0.02
#     class counts:     7     1
#    probabilities: 0.875 0.125
#
# Node number 19: 13 observations
#   predicted class=2  expected loss=0.3076923  P(node) =0.0325
#     class counts:     4     9
#    probabilities: 0.308 0.692
#
# Node number 26: 28 observations,    complexity param=0.015
#   predicted class=1  expected loss=0.4285714  P(node) =0.07
#     class counts:    16    12
#    probabilities: 0.571 0.429
#   left son=52 (7 obs) right son=53 (21 obs)
#   Primary splits:
#       Installment.rate.in.percentage.of.disposable.income splits as  LLRLR,      improve=3.4285710, (0 missing)
#       Duration.in.month                                   < 11.5   to the left,  improve=2.6733500, (0 missing)
#       Other.installment.plans                             splits as  RRL,        improve=1.5238100, (0 missing)
#       Number.of.existing.credits.at.this.bank             < 1.5    to the right, improve=1.3392860, (0 missing)
#       Age.in.years                                        < 39.5   to the left,  improve=0.8800611, (0 missing)
#   Surrogate splits:
#       Duration.in.month          < 10.5   to the left,  agree=0.893, adj=0.571, (0 split)
#       Other.debtors...guarantors splits as  RLRR,       agree=0.821, adj=0.286, (0 split)
#       Age.in.years               < 64     to the right, agree=0.786, adj=0.143, (0 split)
#
# Node number 27: 48 observations
#   predicted class=2  expected loss=0.2291667  P(node) =0.12
#     class counts:    11    37
#    probabilities: 0.229 0.771
#
# Node number 52: 7 observations
#   predicted class=1  expected loss=0  P(node) =0.0175
#     class counts:     7     0
#    probabilities: 1.000 0.000
#
# Node number 53: 21 observations
#   predicted class=2  expected loss=0.4285714  P(node) =0.0525
#     class counts:     9    12
#    probabilities: 0.429 0.571

# %%
# %%R
# rpart.plot(credit_model1)

# %%
# %%R
#  print(confusionMatrix(as.factor(credit_test$V21), as.factor(pred1)))
#
#
#  print(confusionMatrix(as.factor(credit_test$V21),as.factor(pred2)))
#
# print( ce(actual = credit_test$V21,
#       predicted = pred1))
#  print(ce(actual = credit_test$V21,
#       predicted = pred2))
# Out:
#      [,1] [,2]
# [1,]    0    0
# [2,]    0  500
#      [,1] [,2]
# [1,]    0    0
# [2,]    0  500
# [1] 0.365
# [1] 0.3383333

# %% [markdown]
# #### Ejercicio Crédito Gini Python

# %% [markdown]
# ## Árboles de Regresión
# Los árboles de regresión sirven para cuando la salida no es una variable categórica, es decir, es numérica.
# Las metricas de regresion mas comunes para evaluar el modelo son:

# %% [markdown]
# <div class="figure">
# <img src="data:image/png;base64,..." />
#
# </div>

# %% [markdown]
# Estas metricas miden la distancia que existe entre el valor proyectado por el modelo versus el valor real.En ambos casos, mientras menor sea el valor de estas metricas, mejor sera el modelo de predicción.

# %% [markdown]
# ### Ejercicio Estudiantes
# Datos del Comportamiento de los estudiantes
# El objetivo de estos datos es predecir la calificación del examen final de los estudiantes de matemáticas en base a las siguientes variables: sexo, edad, dirección, tiempo de estudio, materia optativa, educación de la familia, pago de extra clase e inasistencias. Para este caso la variable respuesta es la calificación final (numerica de 0 a 20). La información puede consultarse en:
# https://archive.ics.uci.edu/ml/datasets/student+performance
# En este ejercicio, se dividen los datos en: Entrenamiento (training), Validación (validation) y Prueba (test).
# Se Introduce una nueva particion (validation) que sera utilizada para seleccionar el “mejor modelo” dentro de un conjunto de modelos.\
# Durante el curso hemos demostrado diversas formas de separar la información en dos conjuntos mediante la función muestra (sample).\
# Para este ejercicio se utilizara nuevamente la función sample, para separar la información en tres conjuntos.
# Sin embargo, en lugar de muestrear los indices, se utilizara la función `sample()` para asignar a cada renglon dentro de alguno de los conjuntos utilizando una distribución de probabilidad.
#
# Dividir la base en train, valid y test
# Abrir los datos y segmentar la base de datos en: train, valid y test

# %%
# %%R
# # Verificar que la tabla tiene 33 variables
# grade_all <- read.csv("AprendizMaquina/2023-1/Regresion/Datos/student-mat.csv", header = TRUE,sep=";")
#
#
# # Seleccionar solo 8 variables
# grade <- select(grade_all,G1,age, address, studytime, schoolsup,famsup,paid, absences)
#
# # Segmentar de forma aleatoria los renglones en 3 conjuntos: train (70%), valid (15%) y test (15%)
# set.seed(1)
# assignment <- sample(1:3, size = nrow(grade), prob = c(.70,.15,.15), replace = TRUE)
#
# # Crear las bases de datos a partir de la segmentación anterior
#
# grade_train <- grade[assignment == 1, ]    # subset the grade data frame to training indices only
# grade_valid <- grade[assignment == 2, ]  # subset the grade data frame to validation indices only
# grade_test <- grade[assignment == 3, ]   # subset the grade data frame to test indices only
# print("n entrenamiento")
# print(nrow(grade_train))
# print("n prueba")
# print(nrow(grade_valid))
# print("n validación")
# print(nrow(grade_test))
# Out:
# [1] "n entrenamiento"
# [1] 282
# [1] "n prueba"
# [1] 57
# [1] "n validación"
# [1] 56

# %% [markdown]
# Se utilizara la tabla “grade_train”" para ajustar un árbol de regresión utilizando la paquetería `rpart()` y visualizarla con `rpart.plot()`. El arbol de regresion se vera identico a un arbol de clasificación con la excepcion de que tendra valores numericos en los nodos en lugar de clases de predicción.\
# Para ajustar un arbol de decision es importante utilizar el metodo `class`, sin embargo para un arbol de regresión se debe utilizar el metodo ``anova``.

# %%
# %%R
# # Modelo de entrenamiento
# grade_model <- rpart(formula = G1 ~ .,
#                      data = grade_train,
#                      method = "anova")
#
# # Ver la salida del modelo
# print(grade_model)
# # Grafica del arbol de decision
# rpart.plot(x = grade_model, yesno = 2, type = 0, extra = 0)
# Out:
# n= 282
#
# node), split, n, deviance, yval
#       * denotes terminal node
#
#   1) root 282 3210.44300 11.152480
#     2) schoolsup=yes 38  197.81580  9.289474 *
#     3) schoolsup=no 244 2860.19700 11.442620
#       6) studytime< 2.5 189 2165.97900 11.010580
#        12) age>=16.5 107 1180.46700 10.551400
#          24) paid=no 64  779.43750 10.093750
#            48) famsup=yes 26  283.84620  9.076923
#              96) absences< 10 14   60.85714  7.285714 *
#              97) absences>=10 12  125.66670 11.166670 *
#            49) famsup=no 38  450.31580 10.789470 *
#          25) paid=yes 43  367.67440 11.232560 *
#        13) age< 16.5 82  933.51220 11.609760
#          26) famsup=yes 49  557.91840 11.040820
#            52) absences>=3 20  114.55000  9.850000
#             104) paid=yes 10   24.10000  8.300000 *
#             105) paid=no 10   42.40000 11.400000 *
#            53) absences< 3 29  395.44830 11.862070
#             106) studytime< 1.5 8   82.87500  8.875000 *
#             107) studytime>=1.5 21  214.00000 13.000000 *
#          27) famsup=no 33  336.18180 12.454550
#            54) studytime>=1.5 13   93.69231 10.846150 *
#            55) studytime< 1.5 20  187.00000 13.500000 *
#       7) studytime>=2.5 55  537.70910 12.927270
#        14) studytime< 3.5 42  404.50000 12.500000
#          28) famsup=yes 28  250.10710 11.821430 *
#          29) famsup=no 14  115.71430 13.857140 *
#        15) studytime>=3.5 13  100.76920 14.307690 *

# %% [markdown]
# Evaluar el modelo de árbol de regresión
# * Paso.1 Predecir la calificación final de todos los estudiantes para el conjunto test.
# * Paso 2. Evaluar el modelo con la metrica RMSE (Root Mean Squared Error). Esta métrica mide la distancia entre las valores proyectados con respecto a los valores reales.

# %%
# %%R
# pred <- predict(object = grade_model,   # model objecto
#                 newdata = grade_test)  # datos test
#
# # Calulo del RMSE
# rmse(actual = grade_test[,1],
#      predicted = pred)
# Out:
# [1] 3.288132

# %% [markdown]
# #### Ejercicio Estudiantes Python

# %% [markdown]
# ### Hiperparámetros del árbol de regresión
# Los hiperparametros de un arbol de regresión se utiliza para ajustar mejor el arbol de decision.
# En general se pueden hacer 3 tipos de ajuste:
# > ``minslip`` = Establece el número minimo de datos requerido para crear la segmentación del nodo del arbol. Por default n = 20
#
# > ``cp``= Parametro de complejidad que va de cero a uno. Entre mas pequeño sea este valor mas complejo sera el arbol(se incrementa el número de segmentos)
#
# > ``maxdepth`` = Profundidad del arbol define el número del nodos del arbol. Por default $n = 30$
#
# La librería ``rpart()`` calcula 10 escenarios de arbol variando el cp los cuales pueden ser analizados con la función ``plotcp()``, para este caso se elegira el valor cp cuyo xerror sea el mas pequeño.
# Una vez definido el valor de cp se puede tunear el modelo con la función ``prune()``, el cual regresa el modelo optimizado.
#
# **Tuneando el modelo**\
# Utiliza la función ``prune`` y encuentra el mejor valor “CP” (Complexity Parameter)

# %%
# %%R
# # Gráfica de la tabla CP
# plotcp(grade_model)
# # Imprimir la tabla CP
# print(grade_model$cptable)
# Out:
#           CP nsplit rel error    xerror       xstd
# 1 0.04811478      0 1.0000000 1.0062722 0.06608725
# 2 0.01852585      2 0.9037704 0.9624249 0.06415029
# 3 0.01826885      6 0.8296670 1.0193308 0.06897311
# 4 0.01728407      9 0.7748605 1.0370579 0.06924046
# 5 0.01496678     10 0.7575764 1.0655160 0.07232291
# 6 0.01107611     11 0.7426097 1.0223726 0.07294958
# 7 0.01000000     13 0.7204575 1.0178562 0.07376690

# %% [markdown]
# Obtener el valor cp obtimo a partir de varios escenarios (cross-validated error)

# %%
# %%R
# opt_index <- which.min(grade_model$cptable[, "xerror"])
# cp_opt <- grade_model$cptable[opt_index, "CP"]
#
# # Tunear el modelo con el valor cp optimo
# grade_model_opt <- prune(tree = grade_model,
#                          cp = cp_opt)
#
# # Grafica del modelo optimo
# rpart.plot(x = grade_model_opt, yesno = 2, type = 0, extra = 0)

# %% [markdown]
# **Selección del Modelo**\
# Modelar diferentes modelos con distintas combinaciones en sus hiperparametros es el objetivo durante la selección del modelo.\
# Para elegir el mejor se debera elegir la metrica de medición que mejor aplique a cada caso particular), pr ejemplo: AUC y/o RMSE.\
# Sin embargo, la elección de hiperparametros para efectuar la combinación solo se puede hacer de forma manual mediante la gunción expand.grid().

# %%
# %%R
# # Establece una lista de posibles valores para minsplit y maxdepth
# minsplit <- seq(1, 4, 1)
# maxdepth <- seq(1, 6, 1)
#
# # Crea u data frame que contenga todas las combinaciones
# hyper_grid <- expand.grid(minsplit = minsplit, maxdepth = maxdepth)
#
# # Revisar la combinación de distintos modelos
# print(head(hyper_grid))
# # Imprimir el número de combinaciones o modelos
# nrow(hyper_grid)
# Out:
#   minsplit maxdepth
# 1        1        1
# 2        2        1
# 3        3        1
# 4        4        1
# 5        1        2
# 6        2        2
# [1] 24

# %% [markdown]
# En este apartado contruiremos un loop para entrenar los modelos u guardar los resultados en una lista llamada “grade_models”

# %%
# %%R
# # Definir el numero de modelos
#
# num_models <- nrow(hyper_grid)
#
# # Crear una lista vacia para guardar los modelos
#
# grade_models <- list()
#
# # Escribir un loop sobre los renglones de los modelos
# for (i in 1:num_models) {
#
#     # Obtener los valores deminsplit, maxdepth  para cada renglon i
#     minsplit <- hyper_grid$minsplit[i]
#     maxdepth <- hyper_grid$maxdepth[i]
#
#     # Entrena el modelo y guardarlo en la lista grade_models
#     grade_models[[i]] <- rpart(formula = G1 ~ .,
#                                data = grade_train,
#                                method = "anova",
#                                minsplit = minsplit,
#                                maxdepth = maxdepth)
# }

# %% [markdown]
# En esta sección se utiliza la tabla de validación (validation) para evaluar el performance de un conjunto de modelos con el fin de obtener el mejor modelo del grupo.
# Todos los modelos del grupo con evaluados con la misma base de validación y el que tenga mejor performance sera considerado como ganador.\
# Una vez que se obtiene el mejor modelo, una estimacion final del performance es computado sobre la base de prueba (test)\
# La tabla de datos de prueba (test) solo debe utilizarse para estimar el performance y no en la selección del modelo.

# %%
# %%R
# # Numero potencial de modelos
# num_models <- length(grade_models)
#
# # Crea un vector vacio para guardar los resultados del RMSE
# rmse_values <- c()
#
# # Escribe un loop sobre el modelo para guardar los valores RMSE
# for (i in 1:num_models) {
#
#     # Actualiza el i - esimo modelo de la lista
#     model <- grade_models[[i]]
#
#     # Genera predicciones
#     pred <- predict(object = model,
#                     newdata = grade_valid)
#
#     # Calcula el valor de RMSE
#     rmse_values[i] <- rmse(actual = grade_valid$G1,
#                            predicted = pred)
# }
#
# # Identifica el modelo con el menor RMSE
# best_model <- grade_models[[which.min(rmse_values)]]
#
# # Imprime los parametros del mejor modelo
# best_model$control
# Out:
# $minsplit
# [1] 2
#
# $minbucket
# [1] 1
#
# $cp
# [1] 0.01
#
# $maxcompete
# [1] 4
#
# $maxsurrogate
# [1] 5
#
# $usesurrogate
# [1] 2
#
# $surrogatestyle
# [1] 0
#
# $maxdepth
# [1] 2
#
# $xval
# [1] 10

# %% [markdown]
# Calcula el RMSE de la base de datos prueba (train)

# %%
# %%R
# # Calcula el RMSE de la base de datos prueba (train)
# pred <- predict(object = best_model,
#                 newdata = grade_test)
# rmse(actual = grade_test$G1,
#      predicted = pred)
# Out:
# [1] 3.040211

# %% [markdown]
# #### Ejercicio Hiperpámetros Python
